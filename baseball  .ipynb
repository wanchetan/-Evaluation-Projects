# %%
# import library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\CHETAN\OneDrive\Desktop\baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# check rows and columns
df.shape
# Out:
# (30, 17)

# %%
# check data types and null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# no nulls values present in features and all data is integres data type except one data ERA is float data type

# %%
# check null values 
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# check unique value and whitespaces 
for i in df:
    x = df[i].value_counts()
    print(x)
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
# ...

# %% [markdown]
#  no null values and whitespace present in data

# %%
# check duplicate data 
df.duplicated().sum()
# Out:
# 0

# %%
# check data statustic 
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# R, 2B, BB, SO, RA, ER, ERA and SHO some right skewness present
#
# AB, H, 3B, HR, SV and E some left skewness present
#
# SB feature is normal distibuted data

# %%
# check skewness 
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# check data distribution 
plt.figure(figsize=(20,15))
plotnumber = 1

for i in df:
    if plotnumber<=17:
        plt.subplot(5,4,plotnumber)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# all feature looks like normal distribution and form a bell curve

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=17:
        plt.subplot(5,4,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# R, ERA,SHO and E is having higher outlier and other feature is normal
#
# delect outlier usning IQR method

# %%
R_IQR = df['R'].quantile(0.75) - df['R'].quantile(0.25)
high_R = df['R'].quantile(0.75) + (1.5 * R_IQR)
R_index = np.where(df['R']>high_R)
df = df.drop(df.index[R_index])

# %%
ERA_IQR = df['ERA'].quantile(0.75) - df['ERA'].quantile(0.25)
high_ERA = df['ERA'].quantile(0.75) + (1.5 * ERA_IQR)
ERA_index = np.where(df['ERA']>high_ERA)
df = df.drop(df.index[ERA_index])

# %%
SHO_IQR = df['SHO'].quantile(0.75) - df['SHO'].quantile(0.25)
high_SHO = df['SHO'].quantile(0.75) + (1.5 * SHO_IQR)
SHO_index = np.where(df['SHO']>high_SHO)
df = df.drop(df.index[SHO_index])

# %%
SV_IQR = df['SV'].quantile(0.75) - df['SV'].quantile(0.25)
high_SV = df['SV'].quantile(0.75) + (1.5 * SV_IQR)
SV_index = np.where(df['SV']>high_SV)
df = df.drop(df.index[SV_index])

# %%
E_IQR = df['E'].quantile(0.75) - df['E'].quantile(0.25)
high_E = df['E'].quantile(0.75) + (1.5 * E_IQR)
E_index = np.where(df['E']>high_E)
df = df.drop(df.index[E_index])

# %%
df.reset_index()
# Out:
#     index   W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0       0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1       1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2       2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3       3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4       4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 5       6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 6       7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 7       9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 8      11  86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57
# 9      12  85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94
# 10     13  76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16
# ...

# %%
plt.figure(figsize=(30,25))
plotnumber = 1

for i in df:
    if plotnumber<=17:
        plt.subplot(5,4,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %%
df.describe()
# Out:
#               W           R           AB            H          2B        3B  \
# count  20.00000   20.000000    20.000000    20.000000   20.000000  20.00000
# mean   79.10000  684.300000  5519.150000  1406.600000  271.950000  30.95000
# std     7.99276   48.977009    73.347245    63.045013   19.964376  11.69109
# min    64.00000  573.000000  5417.000000  1324.000000  236.000000  13.00000
# 25%    74.00000  654.500000  5458.500000  1362.500000  259.250000  20.75000
# 50%    80.00000  692.500000  5530.000000  1381.500000  273.000000  28.00000
# 75%    84.25000  721.000000  5571.250000  1480.750000  289.000000  40.50000
# max    95.00000  764.000000  5649.000000  1515.000000  303.000000  49.00000
#
#                HR          BB           SO          SB          RA  \
# count   20.000000   20.000000    20.000000   20.000000   20.000000
# mean   164.100000  459.650000  1234.750000   82.900000  700.150000
# std     33.207323   51.464116   101.688831   26.700877   62.646271
# ...

# %%
df.shape
# Out:
# (20, 17)

# %%
# check feature and label relation using scatter plot
plt.figure(figsize=(20,15))
plotnumber= 1

for i in df:
    if plotnumber<=17:
        plt.subplot(5,4,plotnumber)
        sns.scatterplot(data=df,x=i,y='W')
        plt.xlabel(i,fontsize=15)
        plt.ylabel('W',fontsize=15)
    plotnumber+=1
plt.show()

# %%
# check feature and label relation and best fit line  usning regplot
plt.figure(figsize=(20,15))
plotnumber= 1

for i in df:
    if plotnumber<=17:
        plt.subplot(5,4,plotnumber)
        sns.regplot(data=df,x=df[i],y='W')
        plt.xlabel(i,fontsize=15)
        plt.ylabel('W',fontsize=15)
    plotnumber+=1
plt.show()

# %%
# sperate feature and label
x = df.drop('W',axis=1)
y = df['W']

# %%
# check feature vs label relation
x.corrwith(y)
# Out:
# R      0.535833
# AB    -0.028666
# H     -0.015688
# 2B     0.466087
# 3B    -0.172859
# HR     0.310097
# BB     0.157470
# SO    -0.145667
# SB    -0.284301
# RA    -0.750745
# ER    -0.721990
# ERA   -0.736345
# CG    -0.009454
# SHO    0.280154
# SV     0.728984
# E     -0.157481
# dtype: float64

# %% [markdown]
# AB, H, 3B, SO, SB, RA, ER, ERA, CG and E this feature is negative relation with label
#
# R, 2B, HR, BB, SHO and SV is positive relation with label
#
# CG, H and AB less contribute to label
#
# RA, ER, ERA  is strongly negative relation with label
#
# SV strongly possitive relation with label

# %%
# checking relation label and feature with graph
x.corrwith(y).plot(kind='bar',grid=True)
# Out:
# <Axes: >

# %% [markdown]
# CG, H, AB is very less contribute to label
#
# SV and R strongly possitive relation with label
#
# ER, RA and ERA is strongly negative relation with label

# %%
# check correlation fearture vs feature 
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.535833 -0.028666 -0.015688  0.466087 -0.172859  0.310097
# R    0.535833  1.000000  0.483634  0.422218  0.544958  0.203533  0.621018
# AB  -0.028666  0.483634  1.000000  0.785883  0.501330  0.494096  0.056133
# H   -0.015688  0.422218  0.785883  1.000000  0.539406  0.687335 -0.222015
# 2B   0.466087  0.544958  0.501330  0.539406  1.000000  0.349730 -0.028969
# 3B  -0.172859  0.203533  0.494096  0.687335  0.349730  1.000000 -0.331586
# HR   0.310097  0.621018  0.056133 -0.222015 -0.028969 -0.331586  1.000000
# BB   0.157470  0.225600 -0.001157 -0.174686  0.301393 -0.494268  0.295241
# SO  -0.145667  0.177860 -0.056341 -0.353949 -0.158952 -0.166779  0.634661
# SB  -0.284301  0.013466  0.349535  0.421657  0.175440  0.560083 -0.167856
# RA  -0.750745 -0.073313  0.371159  0.302863 -0.181240  0.397549 -0.102877
# ER  -0.721990 -0.026963  0.406950  0.368746 -0.182795  0.444676 -0.079008
# ...

# %% [markdown]
# CG is very less contribute with label also AB and H fearture
#
# RA, ER, ERA is negative relation with label
#
# SV and R is possitive relation with label
#
# RA,ERA and ER have multicolinearity problem

# %%
# check multicolinearity problem
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# CG is very less contribute with label also AB and H fearture
#
# RA, ER, ERA is negative relation with label
#
# SV  is possitive relation with label
#
# RA,ERA and ER have multicolinearity problem

# %%
# check multicolinearity problem using vif method 
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaled = StandardScaler()
scaler = pd.DataFrame(scaled.fit_transform(x),columns=x.columns)
scaler
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.831642  0.781228  1.471146  1.441502  0.969718 -0.775493 -1.528079
# 1   0.245094 -0.729472 -0.937368  0.259522  1.145233 -0.250259 -0.411674
# 2  -0.320507 -1.121135 -0.188775  1.595674 -0.171127 -0.713701  1.462291
# 3  -1.305071  0.193733 -0.416608 -0.614116 -0.346641 -0.868182 -1.109427
# 4   0.098456  1.200866  1.764074  0.876207  1.584019 -0.404740 -0.092701
# 5   1.669569  0.669324 -0.156228  0.002570 -1.048700  1.479925  1.880943
# 6   0.601212 -0.477689 -0.595619 -1.333582 -0.960942  1.634406 -0.830326
# 7   1.334398  1.690445  1.438599  1.133160  0.179902 -0.095778  0.365822
# 8   0.936383 -0.841376 -0.709535  0.310912 -0.434399  2.036056  0.525308
# 9  -0.488092 -1.428870 -1.230295 -1.487754 -0.873185  0.367664 -0.491417
# 10 -0.592833  0.347601 -0.449155 -0.511335 -0.785428  1.047379  0.365822
# 11 -0.928004  0.725276 -0.400334 -0.768287 -0.346641  0.089599  0.724666
# ...

# %%
X = []
for i in range(scaler.shape[1]):
    v = variance_inflation_factor(scaler,i)
    X.append(v)
vif = pd.DataFrame()
vif['vif_score'] = X
vif['feature'] = x.columns

# %%
# check vif score
vif
# Out:
#        vif_score feature
# 0      83.438004       R
# 1     162.704667      AB
# 2      36.125033       H
# 3      29.315360      2B
# 4      95.576597      3B
# 5      72.709544      HR
# 6      28.825427      BB
# 7      11.026216      SO
# 8       8.806245      SB
# 9     412.954942      RA
# 10  13458.876631      ER
# 11   9511.251847     ERA
# 12     10.542916      CG
# 13      6.256707     SHO
# 14     15.320146      SV
# 15      7.048332       E

# %% [markdown]
# ER is more vif score consider delecte this feature and again check multicolinearity problem

# %%
df.drop('ER',axis=1,inplace=True)

# %%
df.drop("CG",axis=1,inplace=True)

# %%
# check multicolinearity problem
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.yticks(rotation=0)
plt.show()

# %%
x = df.drop('W',axis=1)
y = df['W']

# %%
Scaler = StandardScaler()
scal = pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)
vif = []
for i in range(scal.shape[1]):
    V = variance_inflation_factor(scal,i)
    vif.append(V)
VIF = pd.DataFrame()
VIF['vif'] = vif
VIF['feature'] = x.columns
VIF
# Out:
#            vif feature
# 0    12.983816       R
# 1     6.997009      AB
# 2    13.273595       H
# 3     4.215912      2B
# 4    11.591580      3B
# 5    11.295472      HR
# 6     4.518066      BB
# 7     6.331892      SO
# 8     3.406084      SB
# 9   133.740367      RA
# 10  119.465619     ERA
# 11    3.505344     SHO
# 12    2.472775      SV
# 13    2.479505       E

# %%
df.drop('ERA',axis=1,inplace=True)

# %%
x = df.drop('W',axis=1)
y = df['W']

# %%
Scaler = StandardScaler()
scal = pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)
vif = []
for i in range(scal.shape[1]):
    V = variance_inflation_factor(scal,i)
    vif.append(V)
VIF = pd.DataFrame()
VIF['vif'] = vif
VIF['feature'] = x.columns
VIF
# Out:
#           vif feature
# 0   12.640246       R
# 1    5.459114      AB
# 2   12.463536       H
# 3    3.783603      2B
# 4   11.557002      3B
# 5    9.893480      HR
# 6    4.385203      BB
# 7    4.389758      SO
# 8    3.370846      SB
# 9    6.602328      RA
# 10   3.139843     SHO
# 11   2.394515      SV
# 12   2.315776       E

# %%
df.drop('R',axis=1,inplace=True)

# %%
x = df.drop('W',axis=1)
y = df['W']

# %%
Scaler = StandardScaler()
scal = pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)
vif = []
for i in range(scal.shape[1]):
    V = variance_inflation_factor(scal,i)
    vif.append(V)
VIF = pd.DataFrame()
VIF['vif'] = vif
VIF['feature'] = x.columns
VIF
# Out:
#          vif feature
# 0   5.313828      AB
# 1   8.239984       H
# 2   3.782070      2B
# 3   6.802550      3B
# 4   3.032553      HR
# 5   3.111490      BB
# 6   4.381409      SO
# 7   2.245716      SB
# 8   4.389752      RA
# 9   2.349237     SHO
# 10  2.309381      SV
# 11  2.166472       E

# %%
# check multicolinearity problem
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.yticks(rotation=0)
plt.show()

# %%
df.shape
# Out:
# (20, 13)

# %%
# import all model building lib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression , Lasso, Ridge, LassoCV, RidgeCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score, GridSearchCV
import xgboost as xgb

# %%
x_train,x_test,y_train,y_test = train_test_split(scal,y,test_size=0.25,random_state=15)

# %%
# linear regression model
LR = LinearRegression()
LR.fit(x_train,y_train)
y_pred = LR.predict(x_test)
print('R2_score:',r2_score(y_test,y_pred))
print('Training Score:',LR.score(x_train,y_train))
print('Testing Score :',LR.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,y_pred))
print('mean squared error :', mean_squared_error(y_test,y_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score: 0.7021598871356125
# Training Score: 0.9961988836234265
# Testing Score : 0.7021598871356125
# mean absolute error : 3.011125558636607
# mean squared error : 12.509284740304278
# Root means squared error : 3.536846722760866

# %%
lassocv = LassoCV(alphas=None,max_iter=10)
lassocv.fit(x_train,y_train)
alpha = lassocv.alpha_
alpha
# Out:
# 0.04153980850098479

# %%
# Lasso regression model 
lasso = Lasso(alpha,max_iter=10)
lasso.fit(x_train,y_train)
lasso_pred = lasso.predict(x_test)
print('R2_score:',r2_score(y_test,lasso_pred))
print('Training Score:',lasso.score(x_train,y_train))
print('Testing Score :',lasso.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,lasso_pred))
print('mean squared error :', mean_squared_error(y_test,lasso_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,lasso_pred)))
# Out:
# R2_score: 0.8170936926032304
# Training Score: 0.9886763076804965
# Testing Score : 0.8170936926032304
# mean absolute error : 2.5939226485033062
# mean squared error : 7.682064910664323
# Root means squared error : 2.7716538222989398

# %%
ridgeCV = RidgeCV(alphas=np.arange(0.001,0.1,0.01))
ridgeCV.fit(x_train,y_train)
alpha = ridgeCV.alpha_

# %%
# Ridge regression model 
ridge = Ridge(alpha=alpha)
ridge.fit(x_train,y_train)
ridge_pred = ridge.predict(x_test)
print('R2_score:',r2_score(y_test,ridge_pred))
print('Training Score:',ridge.score(x_train,y_train))
print('Testing Score :',ridge.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,ridge_pred))
print('mean squared error :', mean_squared_error(y_test,ridge_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,ridge_pred)))
# Out:
# R2_score: 0.7648968003427921
# Training Score: 0.9959256873484972
# Testing Score : 0.7648968003427921
# mean absolute error : 2.804241217031836
# mean squared error : 9.874334385602731
# Root means squared error : 3.1423453638329972

# %%
# GradientBoosting regression model 
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
gb_pred = gb.predict(x_test)
print('R2_score:',r2_score(y_test,gb_pred))
print('Training Score:',gb.score(x_train,y_train))
print('Testing Score :',gb.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,gb_pred))
print('mean squared error :', mean_squared_error(y_test,gb_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,gb_pred)))
# Out:
# R2_score: -0.5154442878627565
# Training Score: 0.9999999925967357
# Testing Score : -0.5154442878627565
# mean absolute error : 7.420669898317411
# mean squared error : 63.64866009023577
# Root means squared error : 7.978011035981072

# %% [markdown]
# gradient boosting regressor R2 score is negative it is not consider

# %%
# Randamforest Regression model 
RF = RandomForestRegressor()
RF.fit(x_train,y_train)
RF_pred = RF.predict(x_test)
print('R2_score:',r2_score(y_test,RF_pred))
print('Training Score:',RF.score(x_train,y_train))
print('Testing Score :',RF.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,RF_pred))
print('mean squared error :', mean_squared_error(y_test,RF_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,RF_pred)))
# Out:
# R2_score: 0.2486995238095241
# Training Score: 0.906763246628131
# Testing Score : 0.2486995238095241
# mean absolute error : 4.713999999999999
# mean squared error : 31.55461999999999
# Root means squared error : 5.617349908987332

# %%
# AdaBoost Regression model
ada = AdaBoostRegressor()
ada.fit(x_train,y_train)
ada_pred = ada.predict(x_test)
print('R2_score:',r2_score(y_test,ada_pred))
print('Training Score:',ada.score(x_train,y_train))
print('Testing Score :',ada.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,ada_pred))
print('mean squared error :', mean_squared_error(y_test,ada_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,ada_pred)))
# Out:
# R2_score: 0.07486772486772486
# Training Score: 0.9948485335046029
# Testing Score : 0.07486772486772486
# mean absolute error : 5.466666666666666
# mean squared error : 38.855555555555554
# Root means squared error : 6.233422459255874

# %%
# KNeighbors Regression model
knn = KNeighborsRegressor()
knn.fit(x_train,y_train)
knn_pred = knn.predict(x_test)
print('R2_score:',r2_score(y_test,knn_pred))
print('Training Score:',knn.score(x_train,y_train))
print('Testing Score :',knn.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,knn_pred))
print('mean squared error :', mean_squared_error(y_test,knn_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,knn_pred)))
# Out:
# R2_score: -0.22304761904761872
# Training Score: 0.4832369942196528
# Testing Score : -0.22304761904761872
# mean absolute error : 6.039999999999997
# mean squared error : 51.36799999999998
# Root means squared error : 7.167147270706804

# %% [markdown]
# KNN model R2 score is negative. it is not consider

# %%
# DecisionTree Regression model
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt_pred = dt.predict(x_test)
print('R2_score:',r2_score(y_test,dt_pred))
print('Training Score:',dt.score(x_train,y_train))
print('Testing Score :',dt.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,dt_pred))
print('mean squared error :', mean_squared_error(y_test,dt_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,dt_pred)))
# Out:
# R2_score: -2.2333333333333334
# Training Score: 1.0
# Testing Score : -2.2333333333333334
# mean absolute error : 11.0
# mean squared error : 135.8
# Root means squared error : 11.653325705565772

# %% [markdown]
# DecisionTree model R2 score is negative

# %%
# support vector machine regression model 
svr = SVR()
svr.fit(x_train,y_train)
svr_pred = svr.predict(x_test)
print('R2_score:',r2_score(y_test,svr_pred))
print('Training Score:',svr.score(x_train,y_train))
print('Testing Score :',svr.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,svr_pred))
print('mean squared error :', mean_squared_error(y_test,svr_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,svr_pred)))
# Out:
# R2_score: -0.9970340419837238
# Training Score: 0.193619836611285
# Testing Score : -0.9970340419837238
# mean absolute error : 8.122032751758871
# mean squared error : 83.8754297633164
# Root means squared error : 9.158353004952168

# %% [markdown]
# support vector regressor R2 score is negative

# %%
# xtreme gradient boosting regression model
xbg = xgb.XGBRegressor()
xbg.fit(x_train,y_train)
xbg_pred = xbg.predict(x_test)
print('R2_score:',r2_score(y_test,xbg_pred))
print('Training Score:',xbg.score(x_train,y_train))
print('Testing Score :',xbg.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,xbg_pred))
print('mean squared error :', mean_squared_error(y_test,xbg_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,xbg_pred)))
# Out:
# R2_score: -0.5839583850005596
# Training Score: 0.9999999945998095
# Testing Score : -0.5839583850005596
# mean absolute error : 7.019888305664063
# mean squared error : 66.52625217002351
# Root means squared error : 8.156362680142633

# %% [markdown]
# Xtreme gradient boosting regressor R2 score is negative

# %%
LR_score = cross_val_score(LR,x_train,y_train,cv=7,scoring='r2')
print(LR_score)
print(LR_score.mean())
print(r2_score(y_test,y_pred) - LR_score.mean())
# Out:
# [  -0.3695323     0.          -35.5717708    -3.05068978    0.5700877
#    -3.04091868 -179.72919976]
# -31.598860518475185
# 32.3010204056108

# %%
lasso_score = cross_val_score(lasso,x_train,y_train,cv=7,scoring='r2')
print(lasso_score)
print(lasso_score.mean())
print(r2_score(y_test,lasso_pred) - lasso_score.mean())
# Out:
# [ -4.56200601   0.         -13.91205654   0.45467296   0.65739225
#   -7.9365311   -2.56601762]
# -3.9806494377542117
# 4.797743130357442

# %%
ridge_score = cross_val_score(ridge,x_train,y_train,cv=7,scoring='r2')
print(ridge_score)
print(ridge_score.mean())
print(r2_score(y_test,ridge_pred) - ridge_score.mean())
# Out:
# [-0.17272317  0.         -8.74448082 -1.98896103  0.82547569 -1.00701066
#  -1.03523711]
# -1.7318481558610177
# 2.49674495620381

# %%
RF_score = cross_val_score(RF,x_train,y_train,cv=7,scoring='r2')
print(RF_score)
print(RF_score.mean())
print(r2_score(y_test,RF_pred) - RF_score.mean())
# Out:
# [  0.43797755   0.         -13.61825     -4.27237551  -3.820292
#   -8.15322812  -5.647125  ]
# -5.010470440597669
# 5.259169964407193

# %%
ada_score = cross_val_score(ada,x_train,y_train,cv=7,scoring='r2')
print(ada_score)
print(ada_score.mean())
print(r2_score(y_test,ada_pred) - ada_score.mean())
# Out:
# [ -0.43197279   0.         -13.5         -3.24489796  -3.42625
#   -7.5625     -11.5       ]
# -5.666517249757045
# 5.74138497462477

# %% [markdown]
# # Ridge regression model is best model

# %% [markdown]
# increase the accuracy

# %%
param_grid = {'alpha': [alpha],
               'max_iter':range(100,1000,10),
               'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg','sag', 'saga', 'lbfgs'],
             'random_state':range(10,200,10)}

# %%
grid_search = GridSearchCV(estimator=Ridge(),param_grid=param_grid,cv=7,scoring='r2')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=Ridge(),
#              param_grid={'alpha': [0.040999999999999995],
#                          'max_iter': range(100, 1000, 10),
#                          'random_state': range(10, 200, 10),
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga', 'lbfgs']},
#              scoring='r2')

# %%
grid_search.best_estimator_
# Out:
# Ridge(alpha=0.040999999999999995, max_iter=990, random_state=50, solver='sag')

# %%
ridg = Ridge(alpha=alpha,max_iter=990,random_state=50,solver='sag')
ridg.fit(x_train,y_train)
ridg_pred = ridg.predict(x_test)
print('R2_score:',r2_score(y_test,ridg_pred))
print('Training Score:',ridg.score(x_train,y_train))
print('Testing Score :',ridg.score(x_test,y_test))
print('mean absolute error :', mean_absolute_error(y_test,ridg_pred))
print('mean squared error :', mean_squared_error(y_test,ridg_pred))
print('Root means squared error :', np.sqrt(mean_squared_error(y_test,ridg_pred)))
# Out:
# R2_score: 0.7700452250551263
# Training Score: 0.9958742906511555
# Testing Score : 0.7700452250551263
# mean absolute error : 2.793101577031527
# mean squared error : 9.658100547684695
# Root means squared error : 3.1077484691790445

# %% [markdown]
# increase 1% r2 score and testing score
#
# decrese .1% mean absolute error and mean squared error

# %%
sns.regplot(x=ridg_pred,y=y_test)
# Out:
# <Axes: ylabel='W'>

# %%
import pickle 
filename = 'baseball.pkl'
pickle.dump(ridg,open(filename,'wb'))

# %%
loaded = pickle.load(open('baseball.pkl','rb'))
loaded.score(x_test,y_test)
# Out:
# 0.7700452250551263
